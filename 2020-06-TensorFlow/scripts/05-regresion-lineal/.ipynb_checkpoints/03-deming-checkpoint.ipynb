# %% [markdown]
# # Regresión de la distancia ortogonal

# %% [markdown]
# $$y = mx +n $$
# Dado $(x_0,y_0)$, se define la distancia entre el punto y la recta anterior como:
# $$d=\frac{|y_0-(mx_0+b)|}{\sqrt{m^2+1}}$$

# %%
import matplotlib.pyplot as plt
import numpy as np
#import tensorflow as tf
# Para que funcione con la version 2 instalada
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from sklearn import datasets

session = tf.Session()
iris = datasets.load_iris()

# %%
x_vals = np.array([x[3] for x in iris.data])
y_vals = np.array([x[0] for x in iris.data])

# %%
batch_size = 50
learning_rate = 0.1

# %%
x_data = tf.placeholder(shape=[None, 1], dtype=tf.float32)
y_target = tf.placeholder(shape=[None, 1], dtype = tf.float32)
m = tf.Variable(tf.random_normal(shape=[1,1]))
n = tf.Variable(tf.random_normal(shape=[1,1]))

# %%
y_predict = tf.add(tf.matmul(x_data, m), n)

# %%
deming_num = tf.abs(tf.subtract(y_target, tf.add(tf.matmul(x_data,m), n))) # n = |y0 - (m*x0 + b)|
demin_den = tf.sqrt(tf.add(tf.square(m), 1.0)) # d = raiz(m^2 + 1)
deming_loss = tf.reduce_mean(tf.truediv(deming_num, demin_den)) # n/d

# %%
init = tf.global_variables_initializer()
session.run(init)

# %%
my_optim = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
train_step = my_optim.minimize(deming_loss)

# %%
loss_vect = []
for i in range(300):
    rand_idx = np.random.choice(len(x_vals), size = batch_size)
    rand_x = np.transpose([x_vals[rand_idx]])
    rand_y = np.transpose([y_vals[rand_idx]])
    session.run(train_step, feed_dict={x_data : rand_x, y_target: rand_y})
    temp_loss = session.run(deming_loss, feed_dict={x_data: rand_x, y_target: rand_y})
    loss_vect.append(temp_loss)
    if(i+1)%20==0:
        print("Paso #"+str(i+1)+", m = "+str(session.run(m))+", n = "+str(session.run(n))+
             "Loss: "+str(temp_loss))
# Out:
# Paso #20, m = [[-5.8222713]], n = [[13.321799]]Loss: 0.6677592
# Paso #40, m = [[-5.828625]], n = [[13.340731]]Loss: 0.7580075
# Paso #60, m = [[-5.8681865]], n = [[13.332618]]Loss: 0.859117
# Paso #80, m = [[-5.8785863]], n = [[13.346033]]Loss: 0.76697975
# Paso #100, m = [[-5.8946023]], n = [[13.356752]]Loss: 0.75637597
# Paso #120, m = [[-5.9043627]], n = [[13.372791]]Loss: 0.79088175
# Paso #140, m = [[-5.908524]], n = [[13.392151]]Loss: 0.704623
# Paso #160, m = [[-5.9238634]], n = [[13.403474]]Loss: 0.72954506
# Paso #180, m = [[-5.937322]], n = [[13.415422]]Loss: 0.8199912
# Paso #200, m = [[-5.945729]], n = [[13.432011]]Loss: 0.7262007
# Paso #220, m = [[-5.957798]], n = [[13.444593]]Loss: 0.779184
# Paso #240, m = [[-5.961337]], n = [[13.464448]]Loss: 0.86638206
# Paso #260, m = [[-5.981456]], n = [[13.471716]]Loss: 0.7504761
# Paso #280, m = [[-5.981866]], n = [[13.493491]]Loss: 0.74013436
# Paso #300, m = [[-6.0008125]], n = [[13.500733]]Loss: 0.70033866

# %%
# Por alguna razon da negativo, estaria mal

[[slope]] = session.run(m)
[[intercept]] = session.run(n)
print(str(slope)+"x+"+str(intercept))
# Out:
# -6.0008125x+13.500733

# %%
best_fit = []
for i in x_vals: 
    best_fit.append(slope * i +intercept)

# %%
plt.plot(x_vals, y_vals, 'o', label = "Iris Data")
plt.plot(x_vals, best_fit, 'r-', label = "Best Deming Regression", linewidth = 3)
plt.legend(loc = "upper left")
plt.title("Regresion Deming")
plt.xlabel("Anchura de pétalos")
plt.ylabel("Longitud de Sépalos")
plt.show()

# %%
plt.plot(loss_vect, 'k-', label="Función de pérdidas")
