# %% [markdown]
# # Predicción de la longitud del sépalo en función de la anchura del pétalo

# %%
import matplotlib.pyplot as plt
import numpy as np

#import tensorflow as tf
# Para que funcione con la version 2 instalada
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

from sklearn import datasets
# Out:
# WARNING:tensorflow:From /home/ncostamagna/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
session = tf.Session()
iris = datasets.load_iris() # Eso el datasets de Iris

# %%
x_vals = np.array([x[3] for x in iris.data])
y_vals = np.array([x[0] for x in iris.data])

# %%
plt.plot(x_vals, y_vals, 'o', label = "Datos")

# %%
learning_rate = 0.05 # rate de aprendizaje
batch_size = 25
x_data = tf.placeholder(shape=[None, 1], dtype=tf.float32)
y_target = tf.placeholder(shape=[None, 1], dtype = tf.float32)
A = tf.Variable(tf.random_normal(shape=[1,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

# %% [markdown]
# $$y = Ax+b$$

# %%
y_predict = tf.add(tf.matmul(x_data, A), b) # defino la prediccion

# %%
loss_l2 = tf.reduce_mean(tf.square(y_target-y_predict)) # funcion de perdidas
my_optim = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
train_step = my_optim.minimize(loss_l2)
init = tf.global_variables_initializer()
session.run(init)

# %%
# Vamos entrenando el algoritmo
loss_vect_l2 = []
for i in range(100):
    rand_idx = np.random.choice(len(x_vals), size = batch_size)
    rand_x = np.transpose([x_vals[rand_idx]])
    rand_y = np.transpose([y_vals[rand_idx]])

    session.run(train_step, feed_dict={x_data: rand_x, y_target: rand_y})
    temp_loss = session.run(loss_l2, feed_dict={x_data:rand_x, y_target: rand_y})
    loss_vect_l2.append(temp_loss)
    if(i+1)%10==0:
        print("Paso #"+str(i+1)+", A="+str(session.run(A))+", b="+str(session.run(b))+
             ", Loss = "+str(temp_loss))
# Out:
# Paso #10, A=[[2.364638]], b=[[2.2646081]], Loss = 1.9452728
# Paso #20, A=[[2.2278988]], b=[[2.8304162]], Loss = 1.2368913
# Paso #30, A=[[1.9447988]], b=[[3.1934025]], Loss = 0.75570786
# Paso #40, A=[[1.7807815]], b=[[3.5331755]], Loss = 0.93103683
# Paso #50, A=[[1.5697877]], b=[[3.701519]], Loss = 0.6207503
# Paso #60, A=[[1.4538136]], b=[[3.887489]], Loss = 0.3816632
# Paso #70, A=[[1.3847747]], b=[[4.0633187]], Loss = 0.2535673
# Paso #80, A=[[1.2749137]], b=[[4.156387]], Loss = 0.3719128
# Paso #90, A=[[1.2386564]], b=[[4.2711663]], Loss = 0.42812875
# Paso #100, A=[[1.1499505]], b=[[4.349999]], Loss = 0.30962333

# %%
[[slope]] = session.run(A)
[[intercept]] = session.run(b)

# %%
print(str(slope)+"x+"+str(intercept))
# Out:
# 1.1499505x+4.349999

# %%
best_fit = []
for i in x_vals:
    best_fit.append(slope*i+intercept)

# %%
plt.plot(x_vals, y_vals, 'o', label = "Datos")
plt.plot(x_vals, best_fit, 'r-', label="Recta de regresión con TF", linewidth=3)
plt.legend(loc = "upper left")
plt.title("Longitud de sépalos vs Anchura de Pétalos")
plt.xlabel("Anchura del Pétalo")
plt.ylabel("Longitud del Sépalo")
plt.show()

# %%
plt.plot(loss_vect_l2, "k-")
plt.title("Función de pérdidas con L2")
plt.xlabel("Iteración del algoritmo")
plt.ylabel("Medida de L2")
plt.show()

# %%
from tensorflow.python.framework import ops
ops.reset_default_graph()
session = tf.Session()

# %%
x_data = tf.placeholder(shape=[None, 1], dtype=tf.float32)
y_target = tf.placeholder(shape=[None, 1], dtype = tf.float32)
A = tf.Variable(tf.random_normal(shape=[1,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

# %%
y_predict = tf.add(tf.matmul(x_data, A), b)

# %%
loss_l1 = tf.reduce_mean(tf.abs(y_target-y_predict))
my_optim = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
train_step = my_optim.minimize(loss_l1)
init = tf.global_variables_initializer()
session.run(init)

# %%
loss_vect_l1 = []
for i in range(1000):
    rand_idx = np.random.choice(len(x_vals), size = batch_size)
    rand_x = np.transpose([x_vals[rand_idx]])
    rand_y = np.transpose([y_vals[rand_idx]])

    session.run(train_step, feed_dict={x_data: rand_x, y_target: rand_y})
    temp_loss = session.run(loss_l1, feed_dict={x_data:rand_x, y_target: rand_y})
    loss_vect_l1.append(temp_loss)
    if(i+1)%10==0:
        print("Paso #"+str(i+1)+", A="+str(session.run(A))+", b="+str(session.run(b))+
             ", Loss = "+str(temp_loss))
# Out:
# Paso #10, A=[[0.9570717]], b=[[1.0481312]], Loss = 3.7066453
# Paso #20, A=[[1.5368718]], b=[[1.5481308]], Loss = 2.3340185
# Paso #30, A=[[2.0622716]], b=[[2.0201304]], Loss = 1.6486408
# Paso #40, A=[[2.1958714]], b=[[2.2921305]], Loss = 1.4036391
# Paso #50, A=[[2.2508712]], b=[[2.5401301]], Loss = 0.90522826
# Paso #60, A=[[2.2262712]], b=[[2.73213]], Loss = 0.80390775
# Paso #70, A=[[2.144871]], b=[[2.8601298]], Loss = 0.9367174
# Paso #80, A=[[2.0190709]], b=[[2.9561296]], Loss = 0.81605357
# Paso #90, A=[[2.0084705]], b=[[3.1201293]], Loss = 0.9169229
# Paso #100, A=[[1.8792707]], b=[[3.212129]], Loss = 0.85452604
# Paso #110, A=[[1.8228707]], b=[[3.3601289]], Loss = 0.87949914
# Paso #120, A=[[1.7576705]], b=[[3.488129]], Loss = 0.68791217
# Paso #130, A=[[1.6348706]], b=[[3.576129]], Loss = 0.60373384
# Paso #140, A=[[1.5090706]], b=[[3.668129]], Loss = 0.5361829
# Paso #150, A=[[1.4118706]], b=[[3.784129]], Loss = 0.6235986
# Paso #160, A=[[1.3688706]], b=[[3.9161289]], Loss = 0.4827787
# Paso #170, A=[[1.2934709]], b=[[4.0441284]], Loss = 0.52181596
# Paso #180, A=[[1.234871]], b=[[4.1521297]], Loss = 0.3989402
# Paso #190, A=[[1.2066712]], b=[[4.25613]], Loss = 0.38432136
# Paso #200, A=[[1.1472712]], b=[[4.3601313]], Loss = 0.3449625
# Paso #210, A=[[1.0862712]], b=[[4.4321313]], Loss = 0.4891999
# Paso #220, A=[[1.0268711]], b=[[4.496131]], Loss = 0.43403313
# Paso #230, A=[[0.97787094]], b=[[4.532131]], Loss = 0.29151496
# Paso #240, A=[[0.99627095]], b=[[4.568131]], Loss = 0.4124061
# Paso #250, A=[[0.94207096]], b=[[4.612131]], Loss = 0.40075696
# Paso #260, A=[[0.9484709]], b=[[4.6721306]], Loss = 0.428168
# Paso #270, A=[[0.91327095]], b=[[4.6881304]], Loss = 0.34200576
# Paso #280, A=[[0.9102709]], b=[[4.7281313]], Loss = 0.29000795
# Paso #290, A=[[0.84287095]], b=[[4.7081313]], Loss = 0.39421463
# Paso #300, A=[[0.8950709]], b=[[4.7441306]], Loss = 0.3591445
# Paso #310, A=[[0.84967095]], b=[[4.744131]], Loss = 0.28840274
# Paso #320, A=[[0.89587086]], b=[[4.7841315]], Loss = 0.32348415
# Paso #330, A=[[0.8504708]], b=[[4.7681313]], Loss = 0.37049156
# Paso #340, A=[[0.8414708]], b=[[4.764131]], Loss = 0.31380266
# Paso #350, A=[[0.82287073]], b=[[4.788131]], Loss = 0.3194357
# Paso #360, A=[[0.8216707]], b=[[4.796131]], Loss = 0.28574958
# Paso #370, A=[[0.8176707]], b=[[4.8001313]], Loss = 0.2960742
# Paso #380, A=[[0.8586706]], b=[[4.836131]], Loss = 0.34955242
# Paso #390, A=[[0.8042705]], b=[[4.7761307]], Loss = 0.38675645
# Paso #400, A=[[0.86807054]], b=[[4.8201313]], Loss = 0.32258278
# Paso #410, A=[[0.83487064]], b=[[4.7961307]], Loss = 0.42505112
# Paso #420, A=[[0.82547057]], b=[[4.7641306]], Loss = 0.30146927
# Paso #430, A=[[0.8440705]], b=[[4.7921295]], Loss = 0.368104
# Paso #440, A=[[0.8046706]], b=[[4.792129]], Loss = 0.4716159
# Paso #450, A=[[0.78667074]], b=[[4.7961283]], Loss = 0.32572165
# Paso #460, A=[[0.8594708]], b=[[4.832128]], Loss = 0.39462113
# Paso #470, A=[[0.8226708]], b=[[4.804127]], Loss = 0.3502188
# Paso #480, A=[[0.8184709]], b=[[4.8241277]], Loss = 0.2257349
# Paso #490, A=[[0.84147096]], b=[[4.8041277]], Loss = 0.3095683
# Paso #500, A=[[0.815071]], b=[[4.8161273]], Loss = 0.27908412
# Paso #510, A=[[0.792271]], b=[[4.8321276]], Loss = 0.24256033
# Paso #520, A=[[0.8286711]], b=[[4.8321266]], Loss = 0.5124739
# Paso #530, A=[[0.84527117]], b=[[4.8081264]], Loss = 0.3535483
# Paso #540, A=[[0.8250712]], b=[[4.792126]], Loss = 0.38054714
# Paso #550, A=[[0.85507125]], b=[[4.772126]], Loss = 0.3636426
# Paso #560, A=[[0.8592713]], b=[[4.788127]], Loss = 0.42157134
# Paso #570, A=[[0.8476713]], b=[[4.7601266]], Loss = 0.34705734
# Paso #580, A=[[0.8684712]], b=[[4.768126]], Loss = 0.3398173
# Paso #590, A=[[0.8898711]], b=[[4.8121266]], Loss = 0.4973307
# Paso #600, A=[[0.8496711]], b=[[4.7841263]], Loss = 0.37043893
# Paso #610, A=[[0.86747116]], b=[[4.8001266]], Loss = 0.33609837
# Paso #620, A=[[0.8546712]], b=[[4.8201265]], Loss = 0.28394702
# Paso #630, A=[[0.8520711]], b=[[4.8281264]], Loss = 0.26417667
# Paso #640, A=[[0.83787113]], b=[[4.8121266]], Loss = 0.41356468
# Paso #650, A=[[0.83827114]], b=[[4.7961264]], Loss = 0.37831417
# Paso #660, A=[[0.8422711]], b=[[4.792126]], Loss = 0.32599318
# Paso #670, A=[[0.86567116]], b=[[4.8241267]], Loss = 0.44986135
# Paso #680, A=[[0.8330712]], b=[[4.8121266]], Loss = 0.250507
# Paso #690, A=[[0.8254712]], b=[[4.8041277]], Loss = 0.33599532
# Paso #700, A=[[0.8244712]], b=[[4.8321276]], Loss = 0.54739904
# Paso #710, A=[[0.7954712]], b=[[4.8401284]], Loss = 0.31003213
# Paso #720, A=[[0.8082712]], b=[[4.8281283]], Loss = 0.30886844
# Paso #730, A=[[0.8340712]], b=[[4.832128]], Loss = 0.34386322
# Paso #740, A=[[0.8248712]], b=[[4.8361287]], Loss = 0.42293742
# Paso #750, A=[[0.8434712]], b=[[4.8441286]], Loss = 0.40084502
# Paso #760, A=[[0.8388712]], b=[[4.8161287]], Loss = 0.40155548
# Paso #770, A=[[0.81707114]], b=[[4.808129]], Loss = 0.55213094
# Paso #780, A=[[0.8234711]], b=[[4.7961283]], Loss = 0.3319278
# Paso #790, A=[[0.85587114]], b=[[4.820128]], Loss = 0.22765961
# Paso #800, A=[[0.84287107]], b=[[4.8081284]], Loss = 0.32782382
# Paso #810, A=[[0.829271]], b=[[4.808129]], Loss = 0.40237495
# Paso #820, A=[[0.84967095]], b=[[4.812128]], Loss = 0.4421212
# Paso #830, A=[[0.79567105]], b=[[4.788128]], Loss = 0.30316323
# Paso #840, A=[[0.843271]], b=[[4.7881284]], Loss = 0.35506687
# Paso #850, A=[[0.873471]], b=[[4.8121285]], Loss = 0.32847244
# Paso #860, A=[[0.843871]], b=[[4.808128]], Loss = 0.4450581
# Paso #870, A=[[0.83867097]], b=[[4.804128]], Loss = 0.39578074
# Paso #880, A=[[0.86507094]], b=[[4.8041277]], Loss = 0.3391288
# Paso #890, A=[[0.84967095]], b=[[4.8081274]], Loss = 0.1710472
# Paso #900, A=[[0.8084709]], b=[[4.7961273]], Loss = 0.45747986
# Paso #910, A=[[0.82487094]], b=[[4.816127]], Loss = 0.36051956
# Paso #920, A=[[0.8690709]], b=[[4.820127]], Loss = 0.4015718
# Paso #930, A=[[0.8398709]], b=[[4.820127]], Loss = 0.3816106
# Paso #940, A=[[0.82967097]], b=[[4.8081264]], Loss = 0.32805407
# Paso #950, A=[[0.815871]], b=[[4.7841268]], Loss = 0.30726454
# Paso #960, A=[[0.889071]], b=[[4.820127]], Loss = 0.29550016
# Paso #970, A=[[0.8374709]], b=[[4.8041267]], Loss = 0.4330468
# Paso #980, A=[[0.8258709]], b=[[4.8001266]], Loss = 0.51491094
# Paso #990, A=[[0.86087084]], b=[[4.820127]], Loss = 0.3504827
# Paso #1000, A=[[0.83807087]], b=[[4.820127]], Loss = 0.43455535

# %%
[[slope]] = session.run(A)
[[intercept]] = session.run(b)

# %%
print(str(slope)+"x+"+str(intercept))
# Out:
# 0.83807087x+4.820127

# %%
best_fit = []
for i in x_vals:
    best_fit.append(slope*i+intercept)

# %%
plt.plot(x_vals, y_vals, 'o', label = "Datos")
plt.plot(x_vals, best_fit, 'r-', label="Recta de regresión con TF", linewidth=3)
plt.legend(loc = "upper left")
plt.title("Longitud de sépalos vs Anchura de Pétalos")
plt.xlabel("Anchura del Pétalo")
plt.ylabel("Longitud del Sépalo")
plt.show()

# %%
plt.plot(loss_vect_l1, 'r-', label = "L1")
plt.plot(loss_vect_l2, 'g--', label = "L2")
plt.title("Funciones de pérdida para regresión lineal")
plt.xlabel("Iteraciones")
plt.ylabel("Pérdida")
plt.legend(loc = "upper right")
plt.show()

# %%
slope*np.mean(x_vals)+intercept
# Out:
# 5.759749668916067

# %%
intercept
# Out:
# 4.3478765

# %%
# Out:
# 1.1986666666666668

# %%
np.mean(y_vals)
# Out:
# 5.843333333333334
